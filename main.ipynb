# %%
# !pip install numpy-quaternion
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.8/51.8 kB 1.3 MB/s eta 0:00:00
# ...

# %%
from PaperAirplaneEuler import PaperAirplaneEuler, EulerOrder
from PaperAirplaneQuaternion import PaperAirplaneQuaternion

# import PaperAirplaneQuaternion, PaperAirplaneEuler

angle = [80.0, 120.0, 60.0]       # 最終姿勢のオイラー角
order = "EulerOrder.XYZ"
frames = PaperAirplaneQuaternion(angle, order)
frames[0].save("animation.gif", save_all=True, append_images=frames[1:],
               loop=0, duration=10)

# %%
len(frames)
# Out:
# 34
